# %% [markdown]
# # 🚀 Notebook d'Entraînement Deep Learning : Double Descente & TabFM (3 000 Epochs)
# Ce notebook permet d'exécuter l'entraînement du Transformer Sur-Paramétré (2.6M param) sur Google Colab / Jupyter avec GPU.

# %%
# 1. Installation des Dépendances
# !pip install -r requirements.txt

# %%
# 2. Lancement de la Pipeline Double Descente (3 000 Epochs Transformer)
# !python3 scripts/train_tabfm_double_descent.py

# %%
# 3. Lancement de la Pipeline 3-Split Standard (Train/Val/Test Holdout)
# !python3 scripts/train_crypto_3split_pipeline.py
